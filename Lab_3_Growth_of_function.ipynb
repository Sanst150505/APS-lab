# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanst150505/APS-lab/blob/main/Lab_3_Growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
import matplotlib.pyplot as plt

# %%
def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )
def is_even_odd(number):
    if number % 2 == 0:
        return "Even", 1
    else:
        return "Odd", 1

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    _, steps_taken = is_even_odd(n)
    time_values.append(steps_taken)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n (or value of number)")
plt.ylabel("Time (Constant Steps)")
plt.title("O(1) Constant Time Complexity (Even/Odd Check)")
plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
def count_greater_than_zero(numbers):
    count = 0
    for num in numbers:
        if num > 0:
            count += 1
    return count

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    count_greater_than_zero(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity (Count > 0)")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
def binary_search(arr, target):
    low = 0
    high = len(arr) - 1
    steps = 0
    while low <= high:
        steps += 1
        mid = (low + high) // 2
        if arr[mid] == target:
            return steps
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return steps
n_values = [2**i for i in range(1, 15)]
time_values = []

for n in n_values:
    data = list(range(n))
    steps_taken = binary_search(data, n - 1)
    time_values.append(steps_taken)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Number of steps (log n)")
plt.title("O(log n) Logarithmic Time Complexity (Binary Search)")
plt.grid(True)
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
def merge_sort(arr):
    steps = 0
    if len(arr) <= 1:
        return arr, steps

    mid = len(arr) // 2
    left_half, left_steps = merge_sort(arr[:mid])
    right_half, right_steps = merge_sort(arr[mid:])

    steps += left_steps + right_steps
    i = j = k = 0
    while i < len(left_half) and j < len(right_half):
        steps += 1
        if left_half[i] < right_half[j]:
            arr[k] = left_half[i]
            i += 1
        else:
            arr[k] = right_half[j]
            j += 1
        k += 1

    while i < len(left_half):
        arr[k] = left_half[i]
        i += 1
        k += 1

    while j < len(right_half):
        arr[k] = right_half[j]
        j += 1
        k += 1

    return arr, steps

n_values = [n for n in range(1, 201, 10)]
time_values = []

for n in n_values:
    data = list(range(n, 0, -1))
    _, steps_taken = merge_sort(data.copy())
    time_values.append(steps_taken)

plt.figure()
plt.plot(n_values, time_values, marker='o')
plt.xlabel("Input size n")
plt.ylabel("Number of steps (n log n)")
plt.title("O(n log n) Log-Linear Time Complexity (Merge Sort)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
def polynomial_time_example(data):
    steps = 0
    n = len(data)
    for i in range(n):
        for j in range(n):
            steps += 1
    return steps

n_values = list(range(1, 101, 5))
time_values = []

for n in n_values:
    data = list(range(n))
    steps_taken = polynomial_time_example(data)
    time_values.append(steps_taken)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Number of steps (n^2)")
plt.title("O(n^2) Polynomial Time Complexity (Nested Loops)")
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
def fibonacci_recursive(n):
    if n <= 1:
        return n, 1
    fib1_val, steps1 = fibonacci_recursive(n - 1)
    fib2_val, steps2 = fibonacci_recursive(n - 2)
    return fib1_val + fib2_val, steps1 + steps2 + 1

n_values = list(range(1, 21))
time_values = []
for n in n_values:
    _, steps_taken = fibonacci_recursive(n)
    time_values.append(steps_taken)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Number of steps (c^n)")
plt.title("O(2^n) Exponential Time Complexity (Recursive Fibonacci)")
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure
import matplotlib.pyplot as plt
import numpy as np

def O_1(n):
    return np.ones_like(n)

def O_log_n(n):
    return np.log(n)

def O_n(n):
    return n

def O_n_log_n(n):
    return n * np.log(n)

def O_n_squared(n):
    return n**2

def O_2_power_n(n):
    return 2**n

n_values = np.linspace(1, 50, 100)

plt.figure(figsize=(12, 8))

plt.plot(n_values, O_1(n_values), label='O(1) - Constant')
plt.plot(n_values, O_log_n(n_values), label='O(log n) - Logarithmic')
plt.plot(n_values, O_n(n_values), label='O(n) - Linear')
plt.plot(n_values, O_n_log_n(n_values), label='O(n log n) - Log-Linear')
plt.plot(n_values, O_n_squared(n_values), label='O(n^2) - Polynomial')

n_exp = np.linspace(1, 10, 10)
plt.plot(n_exp, O_2_power_n(n_exp))

plt.xlabel('Input Size (n)')
plt.ylabel('Time Complexity')
plt.title('Comparison of Time Complexities')
plt.show()

# %%
def quick_sort(arr):
    steps = 0
    if len(arr) <= 1:
        return arr, 1

    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    steps += len(arr) * 3

    sorted_left, steps_left = quick_sort(left)
    sorted_right, steps_right = quick_sort(right)

    steps += steps_left + steps_right

    return sorted_left + middle + sorted_right, steps

import matplotlib.pyplot as plt
import numpy as np

n_values = [n for n in range(1, 201, 10)]
time_values = []

for n in n_values:
    data = list(np.random.randint(0, 1000, n))
    _, steps_taken = quick_sort(data.copy())
    time_values.append(steps_taken)

plt.figure(figsize=(10, 6))
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Number of steps")
plt.title("Quick Sort Time Complexity (Average Case O(n log n))")
plt.show()
